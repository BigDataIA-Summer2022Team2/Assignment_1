# %% [markdown]
# # Edit Your Expectation Suite
# Use this notebook to recreate and modify your expectation suite:
#
# **Expectation Suite Name**: `MetadataSuite`

# %%
import datetime

import pandas as pd

import great_expectations as ge
import great_expectations.jupyter_ux
from great_expectations.core.batch import BatchRequest
from great_expectations.checkpoint import SimpleCheckpoint
from great_expectations.exceptions import DataContextError

context = ge.data_context.DataContext()

# Note that if you modify this batch request, you may save the new version as a .json file
#  to pass in later via the --batch-request option
batch_request = {'datasource_name': 'my_datasource', 'data_connector_name': 'default_inferred_data_connector_name', 'data_asset_name': 'MetaData.csv', 'limit': 1000}


# Feel free to change the name of your suite here. Renaming this will not remove the other one.
expectation_suite_name = "MetadataSuite"
try:
    suite = context.get_expectation_suite(expectation_suite_name=expectation_suite_name)
    print(f'Loaded ExpectationSuite "{suite.expectation_suite_name}" containing {len(suite.expectations)} expectations.')
except DataContextError:
    suite = context.create_expectation_suite(expectation_suite_name=expectation_suite_name)
    print(f'Created ExpectationSuite "{suite.expectation_suite_name}".')


validator = context.get_validator(
    batch_request=BatchRequest(**batch_request),
    expectation_suite_name=expectation_suite_name
)
column_names = [f'"{column_name}"' for column_name in validator.columns()]
print(f"Columns: {', '.join(column_names)}.")
validator.head(n_rows=5, fetch_all=False)
# Out:
# 2022-06-15T18:31:25-0400 - INFO - Great Expectations logging enabled at 20 level by JupyterUX module.
# C:\Python39\lib\site-packages\great_expectations\datasource\data_connector\runtime_data_connector.py:133: DeprecationWarning: Specifying batch_identifiers as part of the RuntimeDataConnector config is deprecated as of v0.15.1 and will be removed by v0.18. Please configure batch_identifiers as part of Assets instead.
#   warnings.warn(
# Loaded ExpectationSuite "MetadataSuite" containing 11 expectations.
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# Columns: "Unnamed: 0", "index", "image_size", "image_Height", "image_Width", "image_Format", "image_mode", "image_Animated", "image_Frames".
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#    Unnamed: 0                                 index   image_size  \
# 0           0  00b2add164cb42440a52064e390ea3d2.jpg  (1280, 850)
# 1           1  00b627cb5578bb036edb01cdcf7b56d9.jpg  (1300, 867)
# ...

# %% [markdown]
# ## Create & Edit Expectations
#
#
# Add expectations by calling specific expectation methods on the `validator` object. They all begin with `.expect_` which makes autocompleting easy using tab.
#
# Because you selected interactive mode, you are now creating or editing an Expectation Suite with validator feedback from the sample batch of data that you specified (see `batch_request`).
#
# Note that if you select manual mode you may still create or edit an Expectation Suite directly, without feedback from the `validator`. See our documentation for more info and examples: [How to create a new Expectation Suite without a sample batch](https://docs.greatexpectations.io/docs/guides/expectations/how_to_create_and_edit_expectations_based_on_domain_knowledge_without_inspecting_data_directly).
#
#
#
# You can see all the available expectations in the **[expectation gallery](https://greatexpectations.io/expectations)**.

# %% [markdown]
# ### Table Expectation(s)

# %%
validator.expect_table_row_count_to_be_between(max_value=200, min_value=200)
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {
#     "observed_value": 200
#   }
# }

# %%
validator.expect_table_columns_to_match_set(column_set=['image_Height', 'index', 'image_size', 'image_Width', 'image_Animated', 'image_Frames', 'Unnamed: 0', 'image_mode', 'image_Format'])
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {
#     "observed_value": [
#       "Unnamed: 0",
#       "index",
#       "image_size",
#       "image_Height",
#       "image_Width",
#       "image_Format",
#       "image_mode",
#       "image_Animated",
#       "image_Frames"
#     ]
#   }
# }

# %% [markdown]
# ### Column Expectation(s)

# %% [markdown]
# #### `image_Height`

# %%
validator.expect_column_values_to_be_between(column='image_Height', max_value=4000, min_value=0)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {
#     "element_count": 200,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   }
# }

# %%
validator.expect_column_to_exist(column='image_Height')
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {}
# }

# %% [markdown]
# #### `image_Width`

# %%
validator.expect_column_values_to_be_between(column='image_Width', max_value=4000, min_value=0)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {
#     "element_count": 200,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   }
# }

# %%
validator.expect_column_to_exist(column='image_Width')
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {}
# }

# %% [markdown]
# #### `image_Frames`

# %%
validator.expect_column_values_to_be_between(column='image_Frames', max_value=1, min_value=1)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {
#     "element_count": 200,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   }
# }

# %%
validator.expect_column_to_exist(column='image_Frames')
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {}
# }

# %% [markdown]
# #### `image_size`

# %%
validator.expect_column_to_exist(column='image_size')
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {}
# }

# %% [markdown]
# #### `image_Format`

# %%
validator.expect_column_to_exist(column='image_Format')
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {}
# }

# %% [markdown]
# #### `image_mode`

# %%
validator.expect_column_to_exist(column='image_mode')
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "success": true,
#   "result": {}
# }

# %% [markdown]
# ## Review & Save Your Expectations
#
# Let's save the expectation suite as a JSON file in the `great_expectations/expectations` directory of your project.
#
# Let's now rebuild your Data Docs, which helps you communicate about your data with both machines and humans.

# %%
print(validator.get_expectation_suite(discard_failed_expectations=False))
validator.save_expectation_suite(discard_failed_expectations=False)

checkpoint_config = {
    "class_name": "SimpleCheckpoint",
    "validations": [
        {
            "batch_request": batch_request,
            "expectation_suite_name": expectation_suite_name
        }
    ]
}
checkpoint = SimpleCheckpoint(
    f"_tmp_checkpoint_{expectation_suite_name}",
    context,
    **checkpoint_config
)
checkpoint_result = checkpoint.run()

context.build_data_docs()

validation_result_identifier = checkpoint_result.list_validation_result_identifiers()[0]
context.open_data_docs(resource_identifier=validation_result_identifier)
# Out:
# 2022-06-15T18:31:26-0400 - INFO - 	11 expectation(s) included in expectation_suite.
# {
#   "meta": {
#     "citations": [
#       {
#         "citation_date": "2022-06-15T04:27:06.953850Z",
#         "comment": "Suite created by Rule-Based Profiler with the configuration included.",
#         "profiler_config": {
#           "config_version": 1.0,
#           "name": "onboarding_data_assistant",
#           "rules": {
#             "categorical_columns_rule": {
#               "domain_builder": {
#                 "allowed_semantic_types_passthrough": [
#                   "logic"
#                 ],
#                 "cardinality_limit_mode": "rel_100",
#                 "class_name": "CategoricalColumnDomainBuilder",
#                 "exclude_column_name_suffixes": [
#                   "_id"
#                 ],
#                 "exclude_column_names": [
#                   "image_Height",
#                   "index",
#                   "image_size",
# ...
