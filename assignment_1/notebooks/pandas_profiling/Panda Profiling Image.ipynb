# %%
import pandas as pd
import glob
import os
from pandas_profiling import ProfileReport

df = pd.read_csv ('MetaData.csv')
profile = ProfileReport(df, title="Pandas Profiling Report")
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TerminatedWorkerError                     Traceback (most recent call last)
# File c:\Python39\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File c:\Python39\lib\site-packages\pandas_profiling\profile_report.py:418, in ProfileReport._repr_html_(self)
#     416 def _repr_html_(self) -> None:
#     417     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418     self.to_notebook_iframe()
#
# File c:\Python39\lib\site-packages\pandas_profiling\profile_report.py:398, in ProfileReport.to_notebook_iframe(self)
#     396 with warnings.catch_warnings():
#     397     warnings.simplefilter("ignore")
# --> 398     display(get_notebook_iframe(self.config, self))
#
# File c:\Python39\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File c:\Python39\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File c:\Python39\lib\site-packages\pandas_profiling\profile_report.py:368, in ProfileReport.to_html(self)
#     360 def to_html(self) -> str:
#     361     """Generate and return complete template as lengthy string
#     362         for using with frameworks.
#     363
#    (...)
#     366
#     367     """
# --> 368     return self.html
#
# File c:\Python39\lib\site-packages\pandas_profiling\profile_report.py:185, in ProfileReport.html(self)
#     182 @property
#     183 def html(self) -> str:
#     184     if self._html is None:
# --> 185         self._html = self._render_html()
#     186     return self._html
#
# File c:\Python39\lib\site-packages\pandas_profiling\profile_report.py:287, in ProfileReport._render_html(self)
#     284 def _render_html(self) -> str:
#     285     from pandas_profiling.report.presentation.flavours import HTMLReport
# --> 287     report = self.report
#     289     with tqdm(
#     290         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     291     ) as pbar:
#     292         html = HTMLReport(copy.deepcopy(report)).render(
#     293             nav=self.config.html.navbar_show,
#     294             offline=self.config.html.use_local_assets,
#    (...)
#     302             version=self.description_set["package"]["pandas_profiling_version"],
#     303         )
#
# File c:\Python39\lib\site-packages\pandas_profiling\profile_report.py:179, in ProfileReport.report(self)
#     176 @property
#     177 def report(self) -> Root:
#     178     if self._report is None:
# --> 179         self._report = get_report_structure(self.config, self.description_set)
#     180     return self._report
#
# File c:\Python39\lib\site-packages\pandas_profiling\profile_report.py:161, in ProfileReport.description_set(self)
#     158 @property
#     159 def description_set(self) -> Dict[str, Any]:
#     160     if self._description_set is None:
# --> 161         self._description_set = describe_df(
#     162             self.config,
#     163             self.df,
#     164             self.summarizer,
#     165             self.typeset,
#     166             self._sample,
#     167         )
#     168     return self._description_set
#
# File c:\Python39\lib\site-packages\pandas_profiling\model\describe.py:95, in describe(config, df, summarizer, typeset, sample)
#      92 correlation_names = get_active_correlations(config)
#      93 pbar.total += len(correlation_names)
# ---> 95 correlations = {
#      96     correlation_name: progress(
#      97         calculate_correlation, pbar, f"Calculate {correlation_name} correlation"
#      98     )(config, df, correlation_name, series_description)
#      99     for correlation_name in correlation_names
#     100 }
#     102 # make sure correlations is not None
#     103 correlations = {
#     104     key: value for key, value in correlations.items() if value is not None
#     105 }
#
# File c:\Python39\lib\site-packages\pandas_profiling\model\describe.py:96, in <dictcomp>(.0)
#      92 correlation_names = get_active_correlations(config)
#      93 pbar.total += len(correlation_names)
#      95 correlations = {
# ---> 96     correlation_name: progress(
#      97         calculate_correlation, pbar, f"Calculate {correlation_name} correlation"
#      98     )(config, df, correlation_name, series_description)
#      99     for correlation_name in correlation_names
#     100 }
#     102 # make sure correlations is not None
#     103 correlations = {
#     104     key: value for key, value in correlations.items() if value is not None
#     105 }
#
# File c:\Python39\lib\site-packages\pandas_profiling\utils\progress_bar.py:11, in progress.<locals>.inner(*args, **kwargs)
#       8 @wraps(fn)
#       9 def inner(*args, **kwargs) -> Any:
#      10     bar.set_postfix_str(message)
# ---> 11     ret = fn(*args, **kwargs)
#      12     bar.update()
#      13     return ret
#
# File c:\Python39\lib\site-packages\pandas_profiling\model\correlations.py:94, in calculate_correlation(config, df, correlation_name, summary)
#      92 correlation = None
#      93 try:
# ---> 94     correlation = correlation_measures[correlation_name].compute(
#      95         config, df, summary
#      96     )
#      97 except (ValueError, AssertionError, TypeError, DataError, IndexError) as e:
#      98     warn_correlation(correlation_name, str(e))
#
# File c:\Python39\lib\site-packages\multimethod\__init__.py:312, in multimethod.__call__(self, *args, **kwargs)
#     310 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     311 try:
# --> 312     return func(*args, **kwargs)
#     313 except TypeError as ex:
#     314     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Python39\lib\site-packages\pandas_profiling\model\pandas\correlations_pandas.py:134, in pandas_phik_compute(config, df, summary)
#     131     warnings.simplefilter("ignore")
#     132     from phik import phik_matrix
# --> 134     correlation = phik_matrix(df[selected_cols], interval_cols=list(intcols))
#     136 return correlation
#
# File c:\Python39\lib\site-packages\phik\phik.py:256, in phik_matrix(df, interval_cols, bins, quantile, noise_correction, dropna, drop_underflow, drop_overflow, verbose, njobs)
#     223 """
#     224 Correlation matrix of bivariate gaussian derived from chi2-value
#     225
#    (...)
#     245 :return: phik correlation matrix
#     246 """
#     248 data_binned, binning_dict = auto_bin_data(
#     249     df=df,
#     250     interval_cols=interval_cols,
#    (...)
#     254     verbose=verbose,
#     255 )
# --> 256 return phik_from_rebinned_df(
#     257     data_binned,
#     258     noise_correction,
#     259     dropna=dropna,
#     260     drop_underflow=drop_underflow,
#     261     drop_overflow=drop_overflow,
#     262     njobs=njobs,
#     263 )
#
# File c:\Python39\lib\site-packages\phik\phik.py:166, in phik_from_rebinned_df(data_binned, noise_correction, dropna, drop_underflow, drop_overflow, njobs)
#     159     phik_list = [
#     160         _calc_phik(co, data_binned[list(co)], noise_correction)
#     161         for co in itertools.combinations_with_replacement(
#     162             data_binned.columns.values, 2
#     163         )
#     164     ]
#     165 else:
# --> 166     phik_list = Parallel(n_jobs=njobs)(
#     167         delayed(_calc_phik)(co, data_binned[list(co)], noise_correction)
#     168         for co in itertools.combinations_with_replacement(
#     169             data_binned.columns.values, 2
#     170         )
#     171     )
#     173 if len(phik_list) == 0:
#     174     return pd.DataFrame(np.nan, index=column_order, columns=column_order)
#
# File c:\Python39\lib\site-packages\joblib\parallel.py:1017, in Parallel.__call__(self, iterable)
#    1014     self._iterating = False
#    1016 with self._backend.retrieval_context():
# -> 1017     self.retrieve()
#    1018 # Make sure that we get a last message telling us we are done
#    1019 elapsed_time = time.time() - self._start_time
#
# File c:\Python39\lib\site-packages\joblib\parallel.py:909, in Parallel.retrieve(self)
#     907 try:
#     908     if getattr(self._backend, 'supports_timeout', False):
# --> 909         self._output.extend(job.get(timeout=self.timeout))
#     910     else:
#     911         self._output.extend(job.get())
#
# File c:\Python39\lib\site-packages\joblib\_parallel_backends.py:562, in LokyBackend.wrap_future_result(future, timeout)
#     559 """Wrapper for Future.result to implement the same behaviour as
#     560 AsyncResults.get from multiprocessing."""
#     561 try:
# --> 562     return future.result(timeout=timeout)
#     563 except LokyTimeoutError:
#     564     raise TimeoutError()
#
# File c:\Python39\lib\concurrent\futures\_base.py:445, in Future.result(self, timeout)
#     443     raise CancelledError()
#     444 elif self._state == FINISHED:
# --> 445     return self.__get_result()
#     446 else:
#     447     raise TimeoutError()
#
# File c:\Python39\lib\concurrent\futures\_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# TerminatedWorkerError: A worker process managed by the executor was unexpectedly terminated. This could be caused by a segmentation fault while calling the function or by an excessive memory usage causing the Operating System to kill the worker.

# %%
#profile.to_file(output_file=".\pandasprofilingimage.html")
profile.to_file(output_file=".\pandasprofilingimage.json")
