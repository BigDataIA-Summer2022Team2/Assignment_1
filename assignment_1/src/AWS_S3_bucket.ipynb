# %%
# pip install awscli
# pip install boto3
# pip install kaggle
import boto3
import os
import re

# %%
#s3resource=boto3.client('s3','us-east-1')
#s3resource.upload_file(KaggleDatasetname,bucket_name,S3storedkaggledatasetname)

# %%
# S3 buckets
mybuckets = boto3.resource(
    service_name='s3',
    region_name='us-east-1',
    aws_access_key_id='AKIAXUUXEPBEC4KILU6U',
    aws_secret_access_key='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'
)

# %%
# Print out bucket names
for bucket in mybuckets.buckets.all():
    print(bucket.name)
# Out:
# damg7245-amazon-s3

# %%
# Print out all objs
sum=0
for obj in mybuckets.Bucket('damg7245-amazon-s3').objects.all():
    key = obj.key
    body = obj.get()['Body'].read()
    print(key,"\n",body)
    sum+=1
print("\n\nTotal (csv + img) files:",sum)
# Out:
# csv/00b2add164cb42440a52064e390ea3d2.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n00b2add164cb42440a52064e390ea3d2,1280,850,B1,322,112,893,618\r\n'
# csv/00b627cb5578bb036edb01cdcf7b56d9.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n00b627cb5578bb036edb01cdcf7b56d9,1300,867,F35,607,204,1202,529\r\n'
# csv/00d4b7ea93ca1417393007c61c519f88.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n00d4b7ea93ca1417393007c61c519f88,1200,675,A10,560,308,647,329\r\n'
# csv/00db76f676528477c66c93c7d24d7524.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n00db76f676528477c66c93c7d24d7524,1280,857,F117,176,263,1280,553\r\n'
# csv/02ad97f03c7abed5eb68b21d3be45113.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n02ad97f03c7abed5eb68b21d3be45113,1280,856,F14,90,135,1076,691\r\n02ad97f03c7abed5eb68b21d3be45113,1280,856,F18,812,53,1280,445\r\n'
# csv/02cf490c16553169edf7a31d27cea041.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n02cf490c16553169edf7a31d27cea041,1000,650,F117,27,88,965,481\r\n'
# csv/03bee5224965f2d87bd397b7ddd50875.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n03bee5224965f2d87bd397b7ddd50875,728,455,SR71,25,61,713,329\r\n'
# csv/03c9ba9a9d35977dee2c6841f948296c.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n03c9ba9a9d35977dee2c6841f948296c,2000,1365,F22,686,1014,1028,1200\r\n03c9ba9a9d35977dee2c6841f948296c,2000,1365,F22,1005,440,1485,588\r\n03c9ba9a9d35977dee2c6841f948296c,2000,1365,B2,1232,136,1720,336\r\n'
# csv/04a2a2d48715c90cb68ad1f7ae787777.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n04a2a2d48715c90cb68ad1f7ae787777,1400,932,F35,104,34,1284,532\r\n'
# csv/04c12d695c46dc285c6e3f40973d30ac.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n04c12d695c46dc285c6e3f40973d30ac,1400,933,SR71,413,321,989,479\r\n'
# csv/04ddc7aba0a295470bcb7016b96ebac1.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n04ddc7aba0a295470bcb7016b96ebac1,1200,800,F35,159,301,696,476\r\n'
# csv/05e5173a5f1c4b63416c69ac5876b0f5.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n05e5173a5f1c4b63416c69ac5876b0f5,1600,906,F14,1,1,1600,595\r\n'
# csv/05f1f551c874aca4ea2769cc0d99d288.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n05f1f551c874aca4ea2769cc0d99d288,1275,1024,F14,416,512,1102,682\r\n05f1f551c874aca4ea2769cc0d99d288,1275,1024,Tu95,133,270,1018,489\r\n'
# csv/07baa6df06ca535cfa03b55ec741554d.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\
csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n6e0dbdfcbcb8408e33ac22c78ccc6ef6,1024,682,RQ4,414,152,889,342\r\n'
# csv/6e5245284553f4fd836fe41c0090365d.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n6e5245284553f4fd836fe41c0090365d,1280,857,E2,956,244,1219,314\r\n'
# csv/6eb1a564eb5f80aab15cf592dcc3863f.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n6eb1a564eb5f80aab15cf592dcc3863f,2000,1125,C130,105,170,1044,514\r\n6eb1a564eb5f80aab15cf592dcc3863f,2000,1125,E2,1153,603,1845,812\r\n'
# csv/6fc5d87c71d9e35468e700c7ef776edc.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n6fc5d87c71d9e35468e700c7ef776edc,1600,1156,Rafale,326,295,1254,595\r\n'
# csv/6ff7106cbfb4727e492382b92fc0d9f4.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n6ff7106cbfb4727e492382b92fc0d9f4,2495,1645,F22,772,913,1868,1323\r\n6ff7106cbfb4727e492382b92fc0d9f4,2495,1645,F22,250,969,1008,1243\r\n'
# csv/7a050e1bf398f5a56b99108ffe7d5106.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n7a050e1bf398f5a56b99108ffe7d5106,650,975,V22,1,1,650,323\r\n'
# csv/7a1054ee4e1158ad3bb2d2d7b1308cc6.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n7a1054ee4e1158ad3bb2d2d7b1308cc6,2100,1378,F14,459,477,1903,801\r\n'
# csv/7a190a0068c99c337eeb71863b1ec297.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n7a190a0068c99c337eeb71863b1ec297,2100,1395,F22,607,480,1211,705\r\n7a190a0068c99c337eeb71863b1ec297,2100,1395,F117,730,703,1269,885\r\n7a190a0068c99c337eeb71863b1ec297,2100,1395,F4,787,801,1246,991\r\n7a190a0068c99c337eeb71863b1ec297,2100,1395,F15,6,826,513,1017\r\n'
# csv/7a35e709361c3d1fe0f650f5fd31a8c7.csv
#  b'filename,width,height,class,xmin,ymin,xmax,ymax\r\n7a35e709361c3d1fe0f650f5fd31a8c7,1280,853,F16,42,178,1234,688\r\n'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\cheng\Desktop\Big-Data-Systems-Intelligence-Analytics-Labs-Summer-2022\assignment_1\src\AWS_S3_bucket.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/cheng/Desktop/Big-Data-Systems-Intelligence-Analytics-Labs-Summer-2022/assignment_1/src/AWS_S3_bucket.ipynb#ch0000004?line=2'>3</a> for obj in mybuckets.Bucket('damg7245-amazon-s3').objects.all():
#       <a href='vscode-notebook-cell:/c%3A/Users/cheng/Desktop/Big-Data-Systems-Intelligence-Analytics-Labs-Summer-2022/assignment_1/src/AWS_S3_bucket.ipynb#ch0000004?line=3'>4</a>     key = obj.key
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cheng/Desktop/Big-Data-Systems-Intelligence-Analytics-Labs-Summer-2022/assignment_1/src/AWS_S3_bucket.ipynb#ch0000004?line=4'>5</a>     body = obj.get()['Body'].read()
#       <a href='vscode-notebook-cell:/c%3A/Users/cheng/Desktop/Big-Data-Systems-Intelligence-Analytics-Labs-Summer-2022/assignment_1/src/AWS_S3_bucket.ipynb#ch0000004?line=5'>6</a>     print(key,"\n",body)
#       <a href='vscode-notebook-cell:/c%3A/Users/cheng/Desktop/Big-Data-Systems-Intelligence-Analytics-Labs-Summer-2022/assignment_1/src/AWS_S3_bucket.ipynb#ch0000004?line=6'>7</a>     sum+=1
#
# File c:\Python39\lib\site-packages\boto3\resources\factory.py:580, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     579 def do_action(self, *args, **kwargs):
# --> 580     response = action(self, *args, **kwargs)
#     582     if hasattr(self, 'load'):
#     583         # Clear cached data. It will be reloaded the next
#     584         # time that an attribute is accessed.
#     585         # TODO: Make this configurable in the future?
#     586         self.meta.data = None
#
# File c:\Python39\lib\site-packages\boto3\resources\action.py:88, in ServiceAction.__call__(self, parent, *args, **kwargs)
#      79 params.update(kwargs)
#      81 logger.debug(
#      82     'Calling %s:%s with %r',
#      83     parent.meta.service_name,
#      84     operation_name,
#      85     params,
#      86 )
# ---> 88 response = getattr(parent.meta.client, operation_name)(*args, **params)
#      90 logger.debug('Response: %r', response)
#      92 return self._response_handler(parent, params, response)
#
# File c:\Python39\lib\site-packages\botocore\client.py:508, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     504     raise TypeError(
#     505         f"{py_operation_name}() only accepts keyword arguments."
#     506     )
#     507 # The "self" in this scope is referring to the BaseClient.
# --> 508 return self._make_api_call(operation_name, kwargs)
#
# File c:\Python39\lib\site-packages\botocore\client.py:898, in BaseClient._make_api_call(self, operation_name, api_params)
#     896 else:
#     897     apply_request_checksum(request_dict)
# --> 898     http, parsed_response = self._make_request(
#     899         operation_model, request_dict, request_context
#     900     )
#     902 self.meta.events.emit(
#     903     'after-call.{service_id}.{operation_name}'.format(
#     904         service_id=service_id, operation_name=operation_name
#    (...)
#     909     context=request_context,
#     910 )
#     912 if http.status_code >= 300:
#
# File c:\Python39\lib\site-packages\botocore\client.py:921, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#     919 def _make_request(self, operation_model, request_dict, request_context):
#     920     try:
# --> 921         return self._endpoint.make_request(operation_model, request_dict)
#     922     except Exception as e:
#     923         self.meta.events.emit(
#     924             'after-call-error.{service_id}.{operation_name}'.format(
#     925                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     929             context=request_context,
#     930         )
#
# File c:\Python39\lib\site-packages\botocore\endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File c:\Python39\lib\site-packages\botocore\endpoint.py:199, in Endpoint._send_request(self, request_dict, operation_model)
#     197 self._update_retries_context(context, attempts)
#     198 request = self.create_request(request_dict, operation_model)
# --> 199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#     202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#    (...)
#     207     exception,
#     208 ):
#     209     attempts += 1
#
# File c:\Python39\lib\site-packages\botocore\endpoint.py:241, in Endpoint._get_response(self, request, operation_model, context)
#     235 def _get_response(self, request, operation_model, context):
#     236     # This will return a tuple of (success_response, exception)
#     237     # and success_response is itself a tuple of
#     238     # (http_response, parsed_dict).
#     239     # If an exception occurs then the success_response is None.
#     240     # If no exception occurs then exception is None.
# --> 241     success_response, exception = self._do_get_response(
#     242         request, operation_model, context
#     243     )
#     244     kwargs_to_emit = {
#     245         'response_dict': None,
#     246         'parsed_response': None,
#     247         'context': context,
#     248         'exception': exception,
#     249     }
#     250     if success_response is not None:
#
# File c:\Python39\lib\site-packages\botocore\endpoint.py:281, in Endpoint._do_get_response(self, request, operation_model, context)
#     279     http_response = first_non_none_response(responses)
#     280     if http_response is None:
# --> 281         http_response = self._send(request)
#     282 except HTTPClientError as e:
#     283     return (None, e)
#
# File c:\Python39\lib\site-packages\botocore\endpoint.py:377, in Endpoint._send(self, request)
#     376 def _send(self, request):
# --> 377     return self.http_session.send(request)
#
# File c:\Python39\lib\site-packages\botocore\httpsession.py:448, in URLLib3Session.send(self, request)
#     445     conn.proxy_headers['host'] = host
#     447 request_target = self._get_request_target(request.url, proxy_url)
# --> 448 urllib_response = conn.urlopen(
#     449     method=request.method,
#     450     url=request_target,
#     451     body=request.body,
#     452     headers=request.headers,
#     453     retries=Retry(False),
#     454     assert_same_host=False,
#     455     preload_content=False,
#     456     decode_content=False,
#     457     chunked=self._chunked(request.headers),
#     458 )
#     460 http_response = botocore.awsrequest.AWSResponse(
#     461     request.url,
#     462     urllib_response.status,
#     463     urllib_response.headers,
#     464     urllib_response,
#     465 )
#     467 if not request.stream_output:
#     468     # Cause the raw stream to be exhausted immediately. We do it
#     469     # this way instead of using preload_content because
#     470     # preload_content will never buffer chunked responses
#
# File c:\Python39\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Python39\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Python39\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Python39\lib\http\client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File c:\Python39\lib\http\client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File c:\Python39\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File c:\Python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Python39\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Python39\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#mybuckets.Bucket('damg7245-amazon-s3').upload_file(Filename='000ec980b5b17156a55093b4bd6004ab.csv', Key='aircraft/000ec980b5b17156a55093b4bd6004ab.csv')

# %%
# s3_bucket_name = "damg7245-amazon-s3"
# path = "/content/sample_data"
# file_list = os.listdir(path)
# csv_count=0
# img_count=0

# for file_name in file_list:
#   csv_file = re.compile('''(.*?).csv''')
#   match_obj = re.findall(csv_file,file_name)
#   if match_obj:
#     file_path= "csv/" + file_name
#     mybuckets.Bucket(s3_bucket_name).upload_file(Filename=file_name, Key=file_path)
#     csv_count+=1
#   else:
#     file_path= "image/" + file_name
#     mybuckets.Bucket(s3_bucket_name).upload_file(Filename=file_name, Key=file_path)
#     img_count+=1

# print(csv_count)
# print(img_count)
